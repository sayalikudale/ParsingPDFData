# %%
import PyPDF2

# %%
import pandas as pd

# %%
column_names = ["Name", "Description"]
securityPatterns_df = pd.DataFrame(columns = column_names)

# %%
columns = list(securityPatterns_df)
data = []
# Folder Path
path = r"/Users/sayali/OneDrive - UW/Capstone/Code/DataPreprocessing/PDFData/secureDesignPatterns.pdf"

# creating a pdf file object 
pdfFileObj = open(path, 'rb') 
read_pdf = PyPDF2.PdfFileReader(pdfFileObj)

initialPages = 7
IndexPages = [6,9,16,26,29,38,48,57,69,75,82,90,94,96,102,106] # define variable for using in loop.

patternName = ['Distrustful Decomposition','PrivSep','Defer to Kernel','Secure Factory','Secure Strategy Factory',
               'Secure Builder Factory','Secure Chain of Responsibility','Secure State Machine','Secure Visitor',
              'Secure Logger','Clear Sensitive Information','Secure Directory','Pathname Canonicalization','Input Validation',
              'Resource Acquisition Is Initialization',]

n = len(IndexPages)
for index, obj in enumerate(IndexPages):
    if index < (n-1):
        start = obj
        end = IndexPages[index + 1 ]
        number_of_pages = range(start+initialPages,end+initialPages)
        page_content=""
        #print(number_of_pages)
        for page_number in number_of_pages:
            page = read_pdf.getPage(page_number)
            page_content += page.extractText()     # concate reading pages.
        
        values =[patternName[index], page_content.replace('| CMU/SEI-2009-TR-010',' ')]
        zipped = zip(columns, values)
        a_dictionary = dict(zipped)
        data.append(a_dictionary)

securityPatterns_df = securityPatterns_df.append(data, True)

# %%
securityPatterns_df
# Out:
#                                       Name  \
# 0                Distrustful Decomposition
# 1                                  PrivSep
# 2                          Defer to Kernel
# 3                           Secure Factory
# 4                  Secure Strategy Factory
# 5                   Secure Builder Factory
# 6           Secure Chain of Responsibility
# 7                     Secure State Machine
# 8                           Secure Visitor
# 9                            Secure Logger
# 10             Clear Sensitive Information
# 11                        Secure Directory
# 12               Pathname Canonicalization
# 13                        Input Validation
# 14  Resource Acquisition Is Initialization
#
#                                           Description
# 0    6   \n2 The Architectural-Level Patterns \n2....
# 1    9   \nThe actual source code for the qmail sy...
# 2    16   \n             // Am I the child? \n    ...
# 3    26   \n3 The Design-Level Patterns \n3.1 Secu...
# 4    29   \n6. Set the concrete secure factory def...
# 5    38   \n  //! The message generator objects to...
# 6    48   \n   try { \n     \n    // Get the appro...
# 7    57   \nGiven information about the current cl...
# 8    69   \n3.5.10 Known Uses \nﬁMethod and appara...
# 9    75   \n4 The Implementation-Level Patterns \n...
# 10   82   \n Windows XP Encrypting File System (EF...
# 11   90   \n(see the previously defined destructor...
# 12   94   \n  /* Handle error */ } \n \nif (remove...
# 13   96   \n /* ... */ \n free(canonical_filename)...
# 14   102   \n  if (GoodName<100>::validate("Corey ...

# %%
securityPatterns_df.to_csv("securityDesignPatternsBookData.csv", index=False)

# %%
securityPatterns_df = pd.read_csv("/Users/sayali/OneDrive - UW/Capstone/Code/DataPreprocessing/PDFData/securityDesignPatternsBookData.csv", encoding="utf-8-sig")

# %%
securityPatterns_df
# Out:
#                                       Name  \
# 0                Distrustful Decomposition
# 1                                  PrivSep
# 2                          Defer to Kernel
# 3                           Secure Factory
# 4                  Secure Strategy Factory
# 5                   Secure Builder Factory
# 6           Secure Chain of Responsibility
# 7                     Secure State Machine
# 8                           Secure Visitor
# 9                            Secure Logger
# 10             Clear Sensitive Information
# 11                        Secure Directory
# 12               Pathname Canonicalization
# 13                        Input Validation
# 14  Resource Acquisition Is Initialization
#
#                                           Description
# 0    6   \n2 The Architectural-Level Patterns \n2....
# 1    9   \nThe actual source code for the qmail sy...
# 2    16   \n             // Am I the child? \n    ...
# 3    26   \n3 The Design-Level Patterns \n3.1 Secu...
# 4    29   \n6. Set the concrete secure factory def...
# 5    38   \n  //! The message generator objects to...
# 6    48   \n   try { \n     \n    // Get the appro...
# 7    57   \nGiven information about the current cl...
# 8    69   \n3.5.10 Known Uses \nﬁMethod and appara...
# 9    75   \n4 The Implementation-Level Patterns \n...
# 10   82   \n Windows XP Encrypting File System (EF...
# 11   90   \n(see the previously defined destructor...
# 12   94   \n  /* Handle error */ } \n \nif (remove...
# 13   96   \n /* ... */ \n free(canonical_filename)...
# 14   102   \n  if (GoodName<100>::validate("Corey ...

# %%
i = 0

# %%
for index, row in securityPatterns_df.iterrows():
    if i > len(securityPatterns_df):
       break
    else:
       f = open(row[0]+'.txt', 'w')
       f.write(row[1])
       f.close()
       i+=1
